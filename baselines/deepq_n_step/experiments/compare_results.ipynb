# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
def load_progress_data(data_path):
    data_frames = []
    for sub_dir in os.listdir(data_path):
        data_frames.append(pd.read_csv(os.path.join(data_path, sub_dir, 'progress.csv'),  sep=','))
    return data_frames

# %%
def plot_data(data_frames = [], xlabel='steps', ylabel='mean 100 episode reward', legend=[], title=''):
    fig, axes = plt.subplots(1,1)
    for data in data_frames:
        axes.plot(data[xlabel], data[ylabel])
    axes.set_xlabel(xlabel)
    axes.set_ylabel(ylabel)
    axes.legend(legend)
    axes.set_title(title)

# %% [markdown]
# # CartPole-v0

# %%
cartpole_dqn_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15-10-45-15_dqn_CartPole_v0"
cartpole_dqn_df = pd.read_csv(cartpole_dqn_path+'\progress.csv', sep=',')

cartpole_1_step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15-10-08-15_dqn_n_step_CartPole_v0_1step"
cartpole_1_step_df = pd.read_csv(cartpole_1_step_path+'\progress.csv', sep=',')

cartpole_2_step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15-11-10-21_dqn_n_step_CartPole_v0_2step"
cartpole_2_step_df = pd.read_csv(cartpole_2_step_path+'\progress.csv', sep=',')

cartpole_3_step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15-11-14-04_dqn_n_step_CartPole_v0_3step"
cartpole_3_step_df = pd.read_csv(cartpole_3_step_path+'\progress.csv', sep=',')

cartpole_4_step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15-11-16-37_dqn_n_step_CartPole_v0_4step"
cartpole_4_step_df = pd.read_csv(cartpole_4_step_path+'\progress.csv', sep=',')

cartpole_5_step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15-10-33-02_dqn_n_step_CartPole_v0_5step"
cartpole_5_step_df = pd.read_csv(cartpole_5_step_path+'\progress.csv', sep=',')

cartpole_6_step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15-11-20-10_dqn_n_step_CartPole_v0_6step"
cartpole_6_step_df = pd.read_csv(cartpole_6_step_path+'\progress.csv', sep=',')

cartpole_10_step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15-11-04-55_dqn_n_step_CartPole_v0_10step"
cartpole_10_step_df = pd.read_csv(cartpole_10_step_path+'\progress.csv', sep=',')

# %%
cartpole_1_step_df.columns
# Out:
# Index(['% time spent exploring', 'episodes', 'mean 100 episode reward',
#        'steps'],
#       dtype='object')

# %%
plot_data(data_frames = [cartpole_dqn_df, cartpole_1_step_df, cartpole_2_step_df, cartpole_3_step_df,
                         cartpole_4_step_df, cartpole_5_step_df, cartpole_6_step_df,
                         cartpole_10_step_df], 
          xlabel='steps', ylabel='mean 100 episode reward',
          legend=['dqn', '1-step', '2-step', '3-step', '4-step', '5-step', '6-step', '10-step'], 
          title='CartPole-v0')

# %% [markdown]
# # Acrobot-v1

# %%
acrobot_dqn_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15-12-04-03_dqn_Acrobot_v1"
acrobot_dqn_df = pd.read_csv(acrobot_dqn_path+'\progress.csv', sep=',')

acrobot_1_step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15-11-32-52_dqn_n_step_Acrobot_v1_1step"
acrobot_1_step_df = pd.read_csv(acrobot_1_step_path+'\progress.csv', sep=',')

acrobot_2_step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15-11-44-26_dqn_n_step_Acrobot_v1_2step"
acrobot_2_step_df = pd.read_csv(acrobot_2_step_path+'\progress.csv', sep=',')

acrobot_3_step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15-11-53-15_dqn_n_step_Acrobot_v1_3step"
acrobot_3_step_df = pd.read_csv(acrobot_3_step_path+'\progress.csv', sep=',')

acrobot_4_step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15-12-17-20_dqn_n_step_Acrobot_v1_4step"
acrobot_4_step_df = pd.read_csv(acrobot_4_step_path+'\progress.csv', sep=',')

acrobot_5_step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15-12-26-39_dqn_n_step_Acrobot_v1_5step"
acrobot_5_step_df = pd.read_csv(acrobot_5_step_path+'\progress.csv', sep=',')

acrobot_6_step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15-12-47-22_dqn_n_step_Acrobot_v1_6step"
acrobot_6_step_df = pd.read_csv(acrobot_6_step_path+'\progress.csv', sep=',')

acrobot_10_step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15-12-35-45_dqn_n_step_Acrobot_v1_10step"
acrobot_10_step_df = pd.read_csv(acrobot_10_step_path+'\progress.csv', sep=',')

# %%
plot_data(data_frames = [acrobot_dqn_df, acrobot_1_step_df, acrobot_2_step_df, acrobot_3_step_df,
                         acrobot_4_step_df, acrobot_5_step_df, acrobot_6_step_df,
                         acrobot_10_step_df], 
          xlabel='steps', ylabel='mean 100 episode reward',
          legend=['dqn', '1-step', '2-step', '3-step', '4-step', '5-step', '6-step', '10-step'], 
          title='Acrobot-v1')

# %% [markdown]
# # MountainCar-v0

# %%
mountaincar_dqn_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15-12-57-41_dqn_MountainCar_v0"
mountaincar_dqn_df = pd.read_csv(mountaincar_dqn_path+'\progress.csv', sep=',')

mountaincar_1_step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15-14-22-45_dqn_n_step_MountainCar_v0_1step"
mountaincar_1_step_df = pd.read_csv(mountaincar_1_step_path+'\progress.csv', sep=',')

mountaincar_2_step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15-14-30-30_dqn_n_step_MountainCar_v0_2step"
mountaincar_2_step_df = pd.read_csv(mountaincar_2_step_path+'\progress.csv', sep=',')

mountaincar_3_step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15-14-38-12_dqn_n_step_MountainCar_v0_3step"
mountaincar_3_step_df = pd.read_csv(mountaincar_3_step_path+'\progress.csv', sep=',')

mountaincar_4_step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15-14-46-33_dqn_n_step_MountainCar_v0_4step"
mountaincar_4_step_df = pd.read_csv(mountaincar_4_step_path+'\progress.csv', sep=',')

mountaincar_5_step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15-14-55-08_dqn_n_step_MountainCar_v0_5step"
mountaincar_5_step_df = pd.read_csv(mountaincar_5_step_path+'\progress.csv', sep=',')

mountaincar_6_step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15-15-04-34_dqn_n_step_MountainCar_v0_6step"
mountaincar_6_step_df = pd.read_csv(mountaincar_6_step_path+'\progress.csv', sep=',')

mountaincar_6_step_run2_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15-15-49-38_dqn_n_step_MountainCar_v0_6step"
mountaincar_6_step_run2_df = pd.read_csv(mountaincar_6_step_run2_path+'\progress.csv', sep=',')

mountaincar_10_step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15-15-59-35_dqn_n_step_MountainCar_v0_10step"
mountaincar_10_step_df = pd.read_csv(mountaincar_10_step_path+'\progress.csv', sep=',')

mountaincar_10_step_run2_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15-16-14-40_dqn_n_step_MountainCar_v0_10step"
mountaincar_10_step_run2_df = pd.read_csv(mountaincar_10_step_run2_path+'\progress.csv', sep=',')

# %%
plot_data(data_frames = [mountaincar_dqn_df, mountaincar_1_step_df, mountaincar_2_step_df, mountaincar_3_step_df,
                         mountaincar_4_step_df, mountaincar_5_step_df, mountaincar_6_step_df, mountaincar_6_step_run2_df,
                         mountaincar_10_step_df, mountaincar_10_step_run2_df], 
          xlabel='steps', ylabel='mean 100 episode reward',
          legend=['dqn', '1-step', '2-step', '3-step', '4-step', '5-step', '6-step', '6-step run2', '10-step', '10-step run2'], 
          title='MountainCar-v0')

# %% [markdown]
# # Plot Mean and Std

# %%
def plot_data_group(data_groups = [], legend=[], title='', xlabel='steps', ylabel='episode reward'):
    fig, axes = plt.subplots(1,1)
    max_steps = 100000
    std_proportion = 1/2#1/4
    for i, group in enumerate(data_groups):
        aggregate = np.zeros((len(group), max_steps))
        for data_i in range(len(group)):
            aggregate[data_i, :] = np.interp(np.arange(0, max_steps), group[data_i]['steps'], group[data_i]['mean 100 episode reward'])
        data_mean = np.mean(aggregate, axis=0)
        data_std = np.std(aggregate, axis=0)
        if i<2:
            linewidth = 4
        else:
            linewidth = 1
        axes.plot(data_mean, linewidth=linewidth)
        axes.fill_between(np.arange(0, max_steps), data_mean+data_std*std_proportion, data_mean-data_std*std_proportion, 
                          alpha=0.1)
    axes.legend(legend, ncol=2)
    axes.set_xlabel(xlabel)
    axes.set_ylabel(ylabel)
    axes.set_title(title)
    plt.savefig('./figures/comparison_{}.jpg'.format(title), dpi=300)

# %%
# CartPole-v0
CartPole_v0_dqn_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15_dqn_CartPole_v0"
CartPole_v0_dqn_dfs = load_progress_data(CartPole_v0_dqn_path)
CartPole_v0_1step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15_dqn_n_step_CartPole_v0_1step"
CartPole_v0_1step_dfs = load_progress_data(CartPole_v0_1step_path)
CartPole_v0_2step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15_dqn_n_step_CartPole_v0_2step"
CartPole_v0_2step_dfs = load_progress_data(CartPole_v0_2step_path)
CartPole_v0_3step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-16_dqn_n_step_CartPole_v0_3step"
CartPole_v0_3step_dfs = load_progress_data(CartPole_v0_3step_path)
CartPole_v0_4step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-16_dqn_n_step_CartPole_v0_4step"
CartPole_v0_4step_dfs = load_progress_data(CartPole_v0_4step_path)
CartPole_v0_5step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15_dqn_n_step_CartPole_v0_5step"
CartPole_v0_5step_dfs = load_progress_data(CartPole_v0_5step_path)
CartPole_v0_10step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-16_dqn_n_step_CartPole_v0_10step"
CartPole_v0_10step_dfs = load_progress_data(CartPole_v0_10step_path)
CartPole_v0_15step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-16_dqn_n_step_CartPole_v0_15step"
CartPole_v0_15step_dfs = load_progress_data(CartPole_v0_15step_path)
CartPole_v0_20step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-16_dqn_n_step_CartPole_v0_20step"
CartPole_v0_20step_dfs = load_progress_data(CartPole_v0_20step_path)
CartPole_v0_25step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-16_dqn_n_step_CartPole_v0_25step"
CartPole_v0_25step_dfs = load_progress_data(CartPole_v0_25step_path)
CartPole_v0_30step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-16_dqn_n_step_CartPole_v0_30step"
CartPole_v0_30step_dfs = load_progress_data(CartPole_v0_30step_path)
CartPole_v0_35step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-16_dqn_n_step_CartPole_v0_35step"
CartPole_v0_35step_dfs = load_progress_data(CartPole_v0_35step_path)
plot_data_group(data_groups = [CartPole_v0_dqn_dfs, CartPole_v0_1step_dfs, CartPole_v0_2step_dfs, CartPole_v0_3step_dfs, 
                               CartPole_v0_4step_dfs, CartPole_v0_5step_dfs, CartPole_v0_10step_dfs, CartPole_v0_15step_dfs,
                               CartPole_v0_20step_dfs, CartPole_v0_25step_dfs, CartPole_v0_30step_dfs, CartPole_v0_35step_dfs], 
                legend=['dqn', '1-step', '2-step', '3-step', '4-step', '5-step', '10-step', '15-step', '20-step', 
                        '25-step', '30-step', '35-step'], title='CartPole-v0')

# Acrobot-v1
Acrobot_v0_dqn_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15_dqn_Acrobot_v1"
Acrobot_v0_dqn_dfs = load_progress_data(Acrobot_v0_dqn_path)
Acrobot_v0_1step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-16_dqn_n_step_Acrobot_v1_1step"
Acrobot_v0_1step_dfs = load_progress_data(Acrobot_v0_1step_path)
Acrobot_v0_2step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15_dqn_n_step_Acrobot_v1_2step"
Acrobot_v0_2step_dfs = load_progress_data(Acrobot_v0_2step_path)
Acrobot_v0_3step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15_dqn_n_step_Acrobot_v1_3step"
Acrobot_v0_3step_dfs = load_progress_data(Acrobot_v0_3step_path)
Acrobot_v0_4step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-16_dqn_n_step_Acrobot_v1_4step"
Acrobot_v0_4step_dfs = load_progress_data(Acrobot_v0_4step_path)
Acrobot_v0_5step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15_dqn_n_step_Acrobot_v1_5step"
Acrobot_v0_5step_dfs = load_progress_data(Acrobot_v0_5step_path)
Acrobot_v0_10step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-16_dqn_n_step_Acrobot_v1_10step"
Acrobot_v0_10step_dfs = load_progress_data(Acrobot_v0_10step_path)
Acrobot_v0_15step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-16_dqn_n_step_Acrobot_v1_15step"
Acrobot_v0_15step_dfs = load_progress_data(Acrobot_v0_15step_path)
Acrobot_v0_20step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-16_dqn_n_step_Acrobot_v1_20step"
Acrobot_v0_20step_dfs = load_progress_data(Acrobot_v0_20step_path)
Acrobot_v0_25step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-16_dqn_n_step_Acrobot_v1_25step"
Acrobot_v0_25step_dfs = load_progress_data(Acrobot_v0_25step_path)
Acrobot_v0_30step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-16_dqn_n_step_Acrobot_v1_30step"
Acrobot_v0_30step_dfs = load_progress_data(Acrobot_v0_30step_path)
Acrobot_v0_35step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-16_dqn_n_step_Acrobot_v1_35step"
Acrobot_v0_35step_dfs = load_progress_data(Acrobot_v0_35step_path)
plot_data_group(data_groups = [Acrobot_v0_dqn_dfs, Acrobot_v0_1step_dfs, Acrobot_v0_2step_dfs, Acrobot_v0_3step_dfs, 
                               Acrobot_v0_4step_dfs, Acrobot_v0_5step_dfs, Acrobot_v0_10step_dfs, Acrobot_v0_15step_dfs,
                               Acrobot_v0_20step_dfs, Acrobot_v0_25step_dfs, Acrobot_v0_30step_dfs,Acrobot_v0_35step_dfs], 
                legend=['dqn', '1-step','2-step', '3-step', '4-step','5-step','10-step','15-step',
                        '20-step','25-step','30-step','35-step'], title='Acrobot-v1')

# MountainCar-v0
mountaincar_v0_dqn_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15_dqn_MountainCar_v0"
mountaincar_v0_dqn_dfs = load_progress_data(mountaincar_v0_dqn_path)
mountaincar_v0_1step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-16_dqn_n_step_MountainCar_v0_1step"
mountaincar_v0_1step_dfs = load_progress_data(mountaincar_v0_1step_path)
mountaincar_v0_2step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-16_dqn_n_step_MountainCar_v0_2step"
mountaincar_v0_2step_dfs = load_progress_data(mountaincar_v0_2step_path)
mountaincar_v0_3step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-16_dqn_n_step_MountainCar_v0_3step"
mountaincar_v0_3step_dfs = load_progress_data(mountaincar_v0_3step_path)
mountaincar_v0_4step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-16_dqn_n_step_MountainCar_v0_4step"
mountaincar_v0_4step_dfs = load_progress_data(mountaincar_v0_4step_path)
mountaincar_v0_5step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-15_dqn_n_step_MountainCar_v0_5step"
mountaincar_v0_5step_dfs = load_progress_data(mountaincar_v0_5step_path)
mountaincar_v0_10step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-16_dqn_n_step_MountainCar_v0_10step"
mountaincar_v0_10step_dfs = load_progress_data(mountaincar_v0_10step_path)
mountaincar_v0_15step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-16_dqn_n_step_MountainCar_v0_15step"
mountaincar_v0_15step_dfs = load_progress_data(mountaincar_v0_15step_path)
mountaincar_v0_20step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-16_dqn_n_step_MountainCar_v0_20step"
mountaincar_v0_20step_dfs = load_progress_data(mountaincar_v0_20step_path)
mountaincar_v0_25step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-16_dqn_n_step_MountainCar_v0_25step"
mountaincar_v0_25step_dfs = load_progress_data(mountaincar_v0_25step_path)
mountaincar_v0_35step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-16_dqn_n_step_MountainCar_v0_35step"
mountaincar_v0_35step_dfs = load_progress_data(mountaincar_v0_35step_path)
mountaincar_v0_30step_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\openai-2019-07-16_dqn_n_step_MountainCar_v0_30step"
mountaincar_v0_30step_dfs = load_progress_data(mountaincar_v0_30step_path)
plot_data_group(data_groups = [mountaincar_v0_dqn_dfs, mountaincar_v0_1step_dfs, mountaincar_v0_2step_dfs, mountaincar_v0_3step_dfs, mountaincar_v0_4step_dfs, 
                               mountaincar_v0_5step_dfs, mountaincar_v0_10step_dfs, mountaincar_v0_15step_dfs, 
                               mountaincar_v0_20step_dfs, mountaincar_v0_25step_dfs,mountaincar_v0_30step_dfs,mountaincar_v0_35step_dfs], 
                legend=['dqn', '1-step', '2-step', '3-step', '4-step', '5-step', '10-step', '15-step', '20-step', '25-step', '30-step', '35-step'], title='MountainCar-v0')
# Out:
# c:\programdata\anaconda3\envs\tf_gpu\lib\site-packages\ipykernel_launcher.py:22: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.

# %%
Pendulum_v0_path = r"C:\Users\Lingheng\Google Drive\git_repos\spinup_data\2019-07-16_ddpg_n_step_Pendulum_v0\2019-07-16_21-31-25-ddpg_n_step_Pendulum_v0_s0"
Pendulum_v0_df = pd.read_csv(Pendulum_v0_path+'\progress.txt', sep='\t')
fig, axes = plt.subplots(1,1)
axes.plot(Pendulum_v0_df['AverageEpRet'])
